# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv')

# %%
df.columns
# Out:
# Index(['date', 'state', 'fips', 'cases', 'deaths'], dtype='object')

# %%
df_NJ = df[df['state']=='New Jersey']

# %%
df_NJ
# Out:
#             date       state  fips   cases  deaths
# 292   2020-03-04  New Jersey    34       1       0
# 312   2020-03-05  New Jersey    34       2       0
# 337   2020-03-06  New Jersey    34       4       0
# 368   2020-03-07  New Jersey    34       4       0
# 403   2020-03-08  New Jersey    34       6       0
# ...          ...         ...   ...     ...     ...
# 7690  2020-07-20  New Jersey    34  178937   15715
# 7745  2020-07-21  New Jersey    34  179230   15737
# 7800  2020-07-22  New Jersey    34  179565   15707
# 7855  2020-07-23  New Jersey    34  179807   15730
# 7910  2020-07-24  New Jersey    34  180265   15765
#
# [143 rows x 5 columns]

# %%
sns.distplot(df_NJ['cases'])

# %%
sns.boxplot(x='cases', y='deaths', data=df_NJ)

# %%
sns.barplot(x='cases', y='deaths', data=df_NJ)
